# %% [markdown]
# ### Importar librerías

# %% [markdown]
# callate dale

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importar dataset

# %%
data = pd.read_csv('CAERS_ASCII_2004_2017Q2.csv', index_col=0)

# %%
data.describe(include= "all")
# Out:
#        RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# count                  90786                53653            90786
# unique                  4020                 5174                2
# top                 8/3/2016             5/6/2012          Suspect
# freq                     243                  128            74558
# mean                     NaN                  NaN              NaN
# std                      NaN                  NaN              NaN
# min                      NaN                  NaN              NaN
# 25%                      NaN                  NaN              NaN
# 50%                      NaN                  NaN              NaN
# 75%                      NaN                  NaN              NaN
# max                      NaN                  NaN              NaN
#
#        PRI_Reported Brand/Product Name  PRI_FDA Industry Code  \
# count                            90786           90786.000000
# ...

# %%
data.head()
# Out:
#             RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# RA_Report #
# 65325                    1/1/2004             8/4/2003          Suspect
# 65325                    1/1/2004             8/4/2003          Suspect
# 65333                    1/1/2004                  NaN          Suspect
# 65335                    1/1/2004           11/24/2003          Suspect
# 65336                    1/1/2004                  NaN          Suspect
#
#                                PRI_Reported Brand/Product Name  \
# RA_Report #
# 65325            MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# 65325            MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# 65333        KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...
# 65335                               ENFAMIL LIPIL BABY FORMULA
# 65336                               ENFIMIL LIPIL BABY FORMULA
#
#              PRI_FDA Industry Code        PRI_FDA Industry Name  \
# RA_Report #
# ...

# %%
data['PRI_Product Role'].value_counts()
# Out:
# PRI_Product Role
# Suspect        74558
# Concomitant    16228
# Name: count, dtype: int64

# %%
data['CI_Age Unit'].value_counts()
# Out:
# CI_Age Unit
# Year(s)          51331
# Not Available    37873
# Month(s)          1253
# Week(s)            174
# Day(s)             147
# Decade(s)            8
# Name: count, dtype: int64

# %%
data['CI_Gender'].value_counts()
# Out:
# CI_Gender
# Female           58924
# Male             26943
# Not Available     4916
# Unknown              2
# Not Reported         1
# Name: count, dtype: int64

# %%
data['PRI_FDA Industry Name'].value_counts()
# Out:
# PRI_FDA Industry Name
# Vit/Min/Prot/Unconv Diet(Human/Animal)     48501
# Cosmetics                                  11733
# Nuts/Edible Seed                            3383
# Vegetables/Vegetable Products               3115
# Soft Drink/Water                            2591
# Bakery Prod/Dough/Mix/Icing                 2543
# Fishery/Seafood Prod                        2382
# Fruit/Fruit Prod                            2239
# Milk/Butter/Dried Milk Prod                 1515
# Dietary Conv Food/Meal Replacements         1420
# Baby Food Prod                              1264
# Cereal Prep/Breakfast Food                  1264
# Mult Food Dinner/Grav/Sauce/Special         1016
# Snack Food Item                              996
# Coffee/Tea                                   872
# Ice Cream Prod                               828
# Choc/Cocoa Prod                              729
# Candy W/O Choc/Special/Chew Gum              614
# Cheese/Cheese Prod                           404
# ...

# %%
data['AEC_One Row Outcomes'].value_counts()
# Out:
# AEC_One Row Outcomes
# NON-SERIOUS INJURIES/ ILLNESS                                                                                                       24370
# OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)                                                                                            19948
# VISITED A HEALTH CARE PROVIDER, OTHER SERIOUS (IMPORTANT MEDICAL EVENTS)                                                             7948
# HOSPITALIZATION                                                                                                                      5760
# VISITED A HEALTH CARE PROVIDER                                                                                                       3156
#                                                                                                                                     ...
# ...

# %% [markdown]
# ## Estandarizar Unidades

# %% [markdown]
# ### Estandarizar unidades a días
# > CI_Age at Adverse & Event CI_Age Unit

# %%
data['age_in_days'] = np.where(data['CI_Age Unit'] == 'Year(s)', data['CI_Age at Adverse Event']*365,
                    np.where(data['CI_Age Unit'] == 'Month(s)', data['CI_Age at Adverse Event']*30.44,
                    np.where(data['CI_Age Unit'] == 'Week(s)', data['CI_Age at Adverse Event']*7,
                    np.where(data['CI_Age Unit'] == 'Day(s)', data['CI_Age at Adverse Event'],
                    np.where(data['CI_Age Unit'] == 'Decade(s)', data['CI_Age at Adverse Event']*3650,
                    np.where(data['CI_Age Unit'] == 'Not Available', np.nan,
                    data['CI_Age at Adverse Event']))))))

# %%
data
# Out:
#             RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# RA_Report #
# 65325                    1/1/2004             8/4/2003          Suspect
# 65325                    1/1/2004             8/4/2003          Suspect
# 65333                    1/1/2004                  NaN          Suspect
# 65335                    1/1/2004           11/24/2003          Suspect
# 65336                    1/1/2004                  NaN          Suspect
# ...                           ...                  ...              ...
# 214516                  6/29/2017            1/20/2017      Concomitant
# 214516                  6/29/2017            1/20/2017      Concomitant
# 214516                  6/29/2017            1/20/2017          Suspect
# 214604                  6/30/2017                  NaN          Suspect
# 214610                  6/30/2017                  NaN          Suspect
#
#                                PRI_Reported Brand/Product Name  \
# RA_Report #
# ...

# %% [markdown]
# Agrupar por unidad y agrupar por grupo hetario

# %%
import matplotlib as plt
import seaborn as sns

# %%
ax = (data['age_in_days']).plot.hist(figsize=(4,4), bins=60)

# %% [markdown]
# >PRI_Product Role as binary outcome

# %% [markdown]
# >AEC_One Row Outcomes

# %% [markdown]
# >SYM_One Row Coded Symptoms
